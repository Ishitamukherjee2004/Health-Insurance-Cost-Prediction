# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head(4)
# Out:
#    Id   age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   1  39.0   male  23.2             91      Yes         0     No  southeast
# 1   2  24.0   male  30.1             87       No         0     No  southeast
# 2   3   NaN   male  33.3             82      Yes         0     No  southeast
# 3   4   NaN   male  33.7             80       No         0     No  northwest
#
#      claim
# 0  1121.87
# 1  1131.51
# 2  1135.94
# 3  1136.40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1340 non-null   int64
#  1   age            1335 non-null   float64
#  2   gender         1340 non-null   object
#  3   bmi            1340 non-null   float64
#  4   bloodpressure  1340 non-null   int64
#  5   diabetic       1340 non-null   object
#  6   children       1340 non-null   int64
#  7   smoker         1340 non-null   object
#  8   region         1337 non-null   object
#  9   claim          1340 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 104.8+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
pd.set_option("display.float_format", "{:.2f}".format) #to display all floating-point numbers with exactly 2 decimal places whenever a DataFrame or Series is printed.

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 2        3   NaN    male 33.30             82      Yes         0     No
# 3        4   NaN    male 33.70             80       No         0     No
# 4        5   NaN    male 34.10            100       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim
# 0     southeast  1121.87
# 1     southeast  1131.51
# ...

# %%
sns.set(style="whitegrid", palette="Set2", font_scale=1.1) #This line sets the default style and appearance for all Seaborn plots that follow.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Id               0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (1332, 10)

# %%
df.describe(include='all')
# Out:
#             Id     age gender     bmi  bloodpressure diabetic  children  \
# count  1332.00 1332.00   1332 1332.00        1332.00     1332   1332.00
# unique     NaN     NaN      2     NaN            NaN        2       NaN
# top        NaN     NaN   male     NaN            NaN       No       NaN
# freq       NaN     NaN    670     NaN            NaN      695       NaN
# mean    674.47   38.09    NaN   30.66          94.19      NaN      1.10
# std     384.70   11.11    NaN    6.12          11.45      NaN      1.21
# min       1.00   18.00    NaN   16.00          80.00      NaN      0.00
# 25%     341.75   29.00    NaN   26.20          86.00      NaN      0.00
# 50%     674.50   38.00    NaN   30.35          92.00      NaN      1.00
# 75%    1007.25   47.00    NaN   34.73          99.00      NaN      2.00
# max    1340.00   60.00    NaN   53.10         140.00      NaN      5.00
#
#        smoker     region    claim
# count    1332       1332  1332.00
# ...

# %%
df.head(5)
# Out:
#    Id   age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   1 39.00   male 23.20             91      Yes         0     No  southeast
# 1   2 24.00   male 30.10             87       No         0     No  southeast
# 7   8 19.00   male 41.10            100       No         0     No  northwest
# 8   9 20.00   male 43.00             86       No         0     No  northwest
# 9  10 30.00   male 53.10             97       No         0     No  northwest
#
#     claim
# 0 1121.87
# 1 1131.51
# 7 1146.80
# 8 1149.40
# 9 1163.46

# %%
numeric_cols = ["age","bmi", "bloodpressure", "children", "claim"]
df[numeric_cols].hist(figsize=(10, 8), color = "skyblue", edgecolor = "black")
plt.title("Distribution of Numeric Features", fontsize=16)
plt.show()

# %%
cat_cols = ["gender", "diabetic", "smoker", "region"]
plt.figure(figsize=(12, 8))

for i, col in enumerate(cat_cols):
    plt.subplot(2, 2, i+1) #Divides the figure into 2 rows and 2 columns. Places each graph in one of the four positions.
    sns.countplot(data=df, x=col, palette="Set2")
    plt.title(f"Distribution of {col}")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\3107270279.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Set2")
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\3107270279.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Set2")
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\3107270279.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Set2")
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\3107270279.py:6: FutureWarning:
#
# ...

# %%
df.groupby(["gender", "smoker"])["claim"].mean().round(2)
# Out:
# gender  smoker
# female  No        8762.30
#         Yes      30679.00
# male    No        8169.25
#         Yes      33042.01
# Name: claim, dtype: float64

# %%
sns.barplot(data = df, x="gender", y="claim", hue="smoker", palette="Set2", estimator="mean", errorbar="sd")
plt.title("Average Claim Amount by Gender and Smoking Status")
# Out:
# Text(0.5, 1.0, 'Average Claim Amount by Gender and Smoking Status')

# %%
pivot_region_diabetic = df.groupby(["region", "diabetic"])["claim"].mean().unstack()

# %%
pivot_region_diabetic.plot(kind="bar", figsize=(10, 6), color=["#FF9999", "#66B2FF"])
plt.title("Average Claim Amount by Region and Diabetes Status")
plt.ylabel("Mean Claim Amount")
plt.show()

# %%
pivot_table = pd.pivot_table(df, values='claim', index='region', columns='smoker', aggfunc='mean')
pivot_table
# Out:
# smoker          No      Yes
# region
# northeast 11666.11 29673.54
# northwest  8076.20 30192.00
# southeast  7444.14 34845.00
# southwest  8294.75 32269.06

# %%
pivot_table = pd.pivot_table(df, values='claim', index='children', columns='diabetic', aggfunc='mean')
pivot_table
# Out:
# diabetic       No      Yes
# children
# 0        12967.40 11985.29
# 1        12730.46 12732.06
# 2        15567.77 14579.36
# 3        13807.61 17091.26
# 4        14106.63 13573.35
# 5         8519.04  9205.59

# %%
numeric_cols
# Out:
# ['age', 'bmi', 'bloodpressure', 'children', 'claim']

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
sns.scatterplot(data=df, x="age", y="claim", hue="smoker", style="gender", palette="Set2")
plt.title("Claim Amount vs Age by Smoking Status and Gender")
plt.show()

# %%
sns.regplot(data=df, x="bmi", y="claim", scatter_kws={"alpha":0.5}, line_kws={"color":"red"})
plt.title("Claim Amount vs BMI")
plt.show()

# %%
sns.boxplot(data=df, x="children", y="claim")
plt.title("Claim Amount Distribution by Number of Children")
plt.show()

# %%
df["age_group"]=pd.cut(df["age"], bins=[0,18,30,45,60,100], labels=["<18","18-30", "31-45", "46-60", "61+"])

# %%
df["age_group"].value_counts()
# Out:
# age_group
# 31-45    553
# 46-60    383
# 18-30    380
# <18       16
# 61+        0
# Name: count, dtype: int64

# %%
sns.barplot(data=df, x="age_group", y="claim", hue="smoker", estimator="mean", errorbar="ci")
plt.title("Average Claim Amount by Age Group and Smoking Status")
plt.show()

# %%
df["bmi_category"]=pd.cut(df["bmi"], bins=[0,18.5,24.9,29.9,100], labels=["Underweight","Normal weight", "Overweight", "Obese"])

# %%
df["bmi_category"].value_counts()
# Out:
# bmi_category
# Obese            702
# Overweight       387
# Normal weight    222
# Underweight       21
# Name: count, dtype: int64

# %%
sns.boxplot(data=df, x="bmi_category", y="claim", hue="smoker")
plt.title("Claim Amount Distribution by BMI Category and Smoking Status")
plt.show()

# %%
region_stats = df.groupby("region").agg(
    smoker_rate = ("smoker", lambda x: (x=="Yes").mean() * 100),
    mean_claim = ("claim", "mean")

).reset_index()

# %%
region_stats
# Out:
#       region  smoker_rate  mean_claim
# 0  northeast        29.00    16889.04
# 1  northwest        16.81    11794.22
# 2  southeast        20.59    13085.50
# 3  southwest        18.47    12723.13

# %%
fig, axl = plt.subplots(1, 2, figsize=(14, 6))
sns.barplot(data=region_stats, x="region", y="smoker_rate", ax=axl[1], alpha = 0.6)
ax2 = axl[1].twinx()
sns.lineplot(data=region_stats, x="region", y="mean_claim", ax=ax2, color="red", marker="o")

axl[1].set_ylabel("Smoker Rate by Region")
ax2.set_ylabel("Mean Claim Amount by Region")

plt.title("Smoker Rate and Mean Claim Amount by Region")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import joblib

# %%
df.columns
# Out:
# Index(['Id', 'age', 'gender', 'bmi', 'bloodpressure', 'diabetic', 'children',
#        'smoker', 'region', 'claim', 'age_group', 'bmi_category'],
#       dtype='object')

# %%
x = df[["age", "gender", "bmi", "bloodpressure", "diabetic", "children", "smoker"]]
y = df["claim"]

# %%
cat_cols = ["gender", "diabetic", "smoker"]
label_encoders={}

# %%
for col in cat_cols:
    le = LabelEncoder()
    x[col] = le.fit_transform(x[col])
    label_encoders[col]=le

    joblib.dump(le, f"{col}_label_encoder.pkl")  # Save the label encoder for future use
# Out:
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\1623995274.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col] = le.fit_transform(x[col])
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\1623995274.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col] = le.fit_transform(x[col])
# C:\Users\ishit\AppData\Local\Temp\ipykernel_5180\1623995274.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
label_encoders
# Out:
# {'gender': LabelEncoder(),
#  'diabetic': LabelEncoder(),
#  'smoker': LabelEncoder()}

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#        age  gender   bmi  bloodpressure  diabetic  children  smoker
# 1287 32.00       0 39.00             96         1         0       1
# 593  41.00       0 31.10             93         0         0       0
# 972  47.00       0 23.10             92         0         0       0
# 428  34.00       0 30.70             90         0         1       0
# 178  60.00       0 32.10             98         0         2       0
# ...    ...     ...   ...            ...       ...       ...     ...
# 1103 36.00       1 23.20             80         1         1       1
# 1138 20.00       1 28.20            107         1         3       1
# 1302 35.00       0 32.50            134         1         0       1
# 868  44.00       1 27.50            104         1         1       0
# 1134 36.00       0 29.60             99         0         4       0
#
# [1065 rows x 7 columns]

# %%
num_cols = ["age", "bmi", "bloodpressure", "children"]
scaler = StandardScaler()

# %%
x_train[num_cols] = scaler.fit_transform(x_train[num_cols])
x_test[num_cols] = scaler.transform(x_test[num_cols])  # Use transform here, not fit_transform

# %%
joblib.dump(scaler, "standard_scaler.pkl")
# Out:
# ['standard_scaler.pkl']

# %%
print(x_train.shape, y_train.shape)
# Out:
# (1065, 7) (1065,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (267, 7) (267,)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor #Sequntially generate trees
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
def evaluate_model(model, x_train, y_train, x_test, y_test):
    y_pred = model.predict(x_test)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    return {"R2": r2, "MAE": mae, "RMSE": rmse}

# %%
results = {}

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
results["Linear Regression"] = evaluate_model(lr, x_train, y_train, x_test, y_test)


best_poly_model = None
best_poly_score = -np.inf

for degree in [2,3]:
    poly = PolynomialFeatures(degree=degree)
    x_train_poly = poly.fit_transform(x_train)
    x_test_poly = poly.transform(x_test)

    poly_lr = LinearRegression()
    poly_lr.fit(x_train_poly, y_train)

    score = poly_lr.score(x_test_poly, y_test)

    if score > best_poly_score:
        best_poly_score = score
        best_poly_model = (degree, poly, poly_lr)

    degree, poly, poly_lr = best_poly_model
    results[f"Polynomial Regression (degree {degree})"] = evaluate_model(poly_lr, poly.fit_transform(x_train), y_train, poly.transform(x_test), y_test)
    print(f"Best Polynomial Regression Model: Degree {degree} with R2 Score: {best_poly_score:.4f}")



    rf = RandomForestRegressor()
    rf_params = {
        'n_estimators': [100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5],
        'min_samples_leaf': [1, 2]
    }
    rf_grid = GridSearchCV(rf, rf_params, cv=3, scoring='r2', n_jobs=-1, verbose=0)
    rf_grid.fit(x_train, y_train)
    best_rf = rf_grid.best_estimator_
    results["random forest"] = evaluate_model(best_rf, x_train, y_train, x_test, y_test)
    print(f"Best Random Forest Model: {rf_grid.best_params_} with R2 Score: {rf_grid.best_score_:.4f}")



    svr = SVR()
    svr_params = {
        'kernel': ['linear', 'rbf', 'poly'],
        'C': [1, 10, 50],
        "epsilon": [0.1, 0.2, 0.3],
        "degree": [2, 3]  # Only relevant for 'poly' kernel
    }
    svr_grid = GridSearchCV(svr, svr_params, cv=3, scoring='r2', n_jobs=-1, verbose=0)
    svr_grid.fit(x_train, y_train)
    best_svr = svr_grid.best_estimator_
    results["SVR"] = evaluate_model(best_svr, x_train, y_train, x_test, y_test)
    print(f"Best SVR Model: {svr_grid.best_params_} with R2 Score: {svr_grid.best_score_:.4f}")




    xgb = XGBRegressor(objective='reg:squarederror', random_state=42)
    xgb_params = {
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2],
        'subsample': [0.8, 1.0]
    }
    xgb_grid = GridSearchCV(xgb, xgb_params, cv=3, scoring='r2', n_jobs=-1, verbose=0)
    xgb_grid.fit(x_train, y_train)
    best_xgb = xgb_grid.best_estimator_
    results["XGBoost"] = evaluate_model(best_xgb, x_train, y_train, x_test, y_test)
    print(f"Best XGBoost Model: {xgb_grid.best_params_} with R2 Score: {xgb_grid.best_score_:.4f}")
# Out:
# Best Polynomial Regression Model: Degree 2 with R2 Score: 0.7758
# Best Random Forest Model: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} with R2 Score: 0.7846
# Best SVR Model: {'C': 50, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'} with R2 Score: 0.4439
# Best XGBoost Model: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} with R2 Score: 0.7891
# Best Polynomial Regression Model: Degree 2 with R2 Score: 0.7758
# Best Random Forest Model: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} with R2 Score: 0.7849
# Best SVR Model: {'C': 50, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'} with R2 Score: 0.4439
# Best XGBoost Model: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} with R2 Score: 0.7891

# %%
results_df = pd.DataFrame(results).T.sort_values(by="R2", ascending=False)
results_df
# Out:
#                                    R2     MAE    RMSE
# XGBoost                          0.83 3828.94 4916.79
# random forest                    0.82 3898.33 5084.05
# Polynomial Regression (degree 2) 0.78 4426.32 5684.83
# Linear Regression                0.72 5034.26 6368.14
# SVR                              0.50 5916.78 8506.15

# %%
best_rf
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=2, min_samples_split=5)

# %%
models = {
    "Linear Regression": lr,
    "Polynomial Regression": poly_lr,
    "Random Forest": best_rf,
    "SVR": best_svr,
    "XGBoost": best_xgb
}

# %%
best_r2 = results_df["R2"].max()
best_r2
# Out:
# 0.8322738188116681

# %%
top_model = results_df["R2"] == best_r2
top_model
# Out:
# XGBoost                              True
# random forest                       False
# Polynomial Regression (degree 2)    False
# Linear Regression                   False
# SVR                                 False
# Name: R2, dtype: bool

# %%
best_model = models[top_model.index[0]]
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
joblib.dump(best_model, "best_model.pkl")  # Save the best model for future use
print(f"Best model saved as 'best_model.pkl': {top_model.index[0]} with R2 Score: {best_r2:.4f}")
# Out:
# Best model saved as 'best_model.pkl': XGBoost with R2 Score: 0.8323

# %%
print(scaler.feature_names_in_)
# Out:
# ['age' 'bmi' 'bloodpressure' 'children']
